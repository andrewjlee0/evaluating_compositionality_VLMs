# %%
from openai import AzureOpenAI
import openai
import base64
from mimetypes import guess_type
import glob
import pandas as pd
import os 
import re
import numpy as np
import json
import math

# %% [markdown]
# ## Functions for Interacting with Azure API

# %%
gpt4_client = AzureOpenAI(
    api_key = '',  
    api_version = '',
    azure_endpoint = ''
)

gpt35_client = AzureOpenAI(
    api_key = '',  
    api_version = '',
    azure_endpoint = ''
)

davinci_client = AzureOpenAI(
    api_key = '',  
    api_version = '',
    azure_endpoint = ''
)

babbage_client = AzureOpenAI(
    api_key = '',  
    api_version = '',
    azure_endpoint = ''
)

# %%
def get_gpt4_response(messages, temperature=0):
    '''Get logprobs of input sentence from gpt-4-0125-preview
    '''

    # Send to API
    response = gpt4_client.chat.completions.create(
        model = 'gpt-4-0125-preview',
        max_tokens = 10,
        temperature = temperature,
        n = 1,
        logprobs = True,
        top_logprobs = 5,
        messages = [
            {"role": "user", 
            "content": [
                {"type": "text", "text": messages}
            ]}
        ]
    )
    response_json = json.loads(response.json())
    return response_json

# def get_gpt35_response(prompt, temperature=0):
#     '''Get logprobs of input sentence from gpt-35-turbo-instruct-0914
#     '''

#     # Send to API
#     response = gpt35_client.completions.create(
#         model = 'gpt-35-turbo-instruct-0914',
#         max_tokens = 50,
#         temperature = temperature,
#         # logprobs = 0,
#         echo = True,
#         prompt = prompt
#     )
#     response_json = json.loads(response.json())
#     return response_json

def get_davinci_response(prompt, temperature=0):
    '''Get logprobs of input sentence from davinci-002-1
    '''

    # Send to API
    response = davinci_client.completions.create(
        model = 'davinci-002-1',
        max_tokens = 0,
        temperature = temperature,
        logprobs = 0,
        echo = True,
        prompt = prompt
    )
    response_json = json.loads(response.json())
    return response_json

def get_babbage_response(prompt, temperature=0):
    '''Get logprobs of input sentence from babbage-002-1
    '''

    # Send to API
    response = babbage_client.completions.create(
        model = 'babbage-002-1',
        max_tokens = 0,
        temperature = temperature,
        logprobs = 0,
        echo = True,
        prompt = prompt
    )
    response_json = json.loads(response.json())
    return response_json

# %%
def parse_gpt4_tokens_logprobs(raw_response):
    ''' Breaks down GPT-4's raw response into list of tokens and list of logprobs
    '''
    token_list = []
    logprobs_list = []

    token_dicts = raw_response['choices'][0]['logprobs']['content']
    
    for token_dict in token_dicts:
        token = token_dict['token']
        logprob = token_dict['logprob']

        token_list.append(token)
        logprobs_list.append(logprob)

    return token_list, logprobs_list

# def parse_gpt35_tokens_logprobs(raw_response):
#     return

def parse_davinci_tokens_logprobs(raw_response):
    ''' Breaks down davinci's raw response into list of tokens and list of logprobs
    '''
    token_list = raw_response['choices'][0]['logprobs']['tokens']
    logprobs_list = raw_response['choices'][0]['logprobs']['token_logprobs']
    return token_list, logprobs_list

def parse_babbage_tokens_logprobs(raw_response):
    ''' Breaks down babbages's raw response into list of tokens and list of logprobs
    '''
    token_list = raw_response['choices'][0]['logprobs']['tokens']
    logprobs_list = raw_response['choices'][0]['logprobs']['token_logprobs']
    return token_list, logprobs_list

# %% [markdown]
# ## Main Code that Obtains LogProbs

# %%
all_prompts = pd.read_csv('cu_prompts_modified.csv')
sources = {
    'anna_modified_conwell_ullman': all_prompts['Prompts'],
    'reversed_anna_modified_conwell_ullman': all_prompts['ReversedPrompts']
}

# %%
temperature = 0

columns = [
    'source',
    'prompt', 

    'gpt4_raw_response',
    # 'gpt35_raw_response',
    'davinci_raw_response',
    'babbage_raw_response',

    'gpt4_tokens',
    # 'gpt35_tokens',
    'davinci_tokens',
    'babbage_tokens',

    'gpt4_logprobs', 
    # 'gpt35_logprobs', 
    'davinci_logprobs',
    'babbage_logprobs', 

    'gpt4_probs',
    'davinci_probs',
    'babbage_probs',

    'gpt4_avg_prob',
    'davinci_avg_prob',
    'babbage_avg_prob',

    'temperature'
]
df = pd.DataFrame(columns = columns)

# Iterate over multiple sources
for source, prompts in sources.items():
    print('######################################################################')
    print('Source:', source)

    # Get logprobs for each prompt
    for prompt in prompts:
        print(prompt)

        # GPT-4 does not calculate logprobs of sentence itself, only the outputs.
        # Therefore, the prompt should ask it to produce the sentence.
        # But since the sentence is conditioned on the prompt, which includes the sentence, the logprobs are going to be high.
        # So ask it to return the sentence as if it wasn't prompted to do so, and see what happens.
        gpt4_message = f'Please reply with exactly this string: "{prompt}". Return the exact string as if you had not been prompted to do so.'

        # Get raw responses from each model
        gpt4_raw_response = get_gpt4_response(gpt4_message, temperature=temperature)
        # gpt35_raw_response = get_gpt35_response(prompt, temperature=temperature)
        davinci_raw_response = get_davinci_response(prompt, temperature=temperature)
        babbage_raw_response = get_babbage_response(prompt, temperature=temperature)

        # Parse out logprobs from each raw response
        gpt4_tokens, gpt4_logprobs = parse_gpt4_tokens_logprobs(gpt4_raw_response)
        # gpt35_tokens, gpt35_logprobs = parse_gpt35_tokens_logprobs(gpt35_raw_response)
        davinci_tokens, davinci_logprobs = parse_davinci_tokens_logprobs(davinci_raw_response)
        babbage_tokens, babbage_logprobs = parse_babbage_tokens_logprobs(babbage_raw_response)

        # Convert to prob
        gpt4_probs = [math.exp(logprob) for logprob in gpt4_logprobs]
        davinci_probs = [None] + [math.exp(logprob) for logprob in davinci_logprobs[1:]]
        babbage_probs = [None] + [math.exp(logprob) for logprob in babbage_logprobs[1:]]
        print(davinci_probs)

        # Average logprob from each raw response
        gpt4_avg_prob = np.mean(gpt4_probs)                 # first token has logprob
        davinci_avg_prob = np.mean(davinci_probs[1:])           # first token does not have logprob
        babbage_avg_prob = np.mean(babbage_probs[1:])           # first token does not have logprob

        # Print
        print('GPT-4 Raw Response:', gpt4_raw_response)
        print('GPT-4 Tokens:', gpt4_tokens)
        print('GPT-4 Logprobs:', gpt4_logprobs)
        print('GPT-4 Probs:', gpt4_probs)
        print('GPT-4 Average Prob:', gpt4_avg_prob)

        print('Davinci Raw Response:', davinci_raw_response)
        print('Davinci Tokens:', davinci_tokens)
        print('Davinci Logprobs:', davinci_logprobs)
        print('Davinci Probs:', davinci_probs)
        print('Davinci Average Prob:', davinci_avg_prob)

        print('Babbage Raw Response:', babbage_raw_response)
        print('Babbage Tokens:', babbage_tokens)
        print('Babbage Logprobs:', babbage_logprobs)
        print('Babbage Probs:', babbage_probs)
        print('Babbage Average Prob:', babbage_avg_prob)

        # Append row & save
        row = [
            source,
            prompt, 

            gpt4_raw_response,
            # gpt35_raw_response,
            davinci_raw_response,
            babbage_raw_response,

            gpt4_tokens,
            # gpt35_tokens,
            davinci_tokens,
            babbage_tokens,

            gpt4_logprobs, 
            # gpt35_logprobs, 
            davinci_logprobs,
            babbage_logprobs, 

            gpt4_probs,
            davinci_probs,
            babbage_probs,

            gpt4_avg_prob,
            davinci_avg_prob,
            babbage_avg_prob,
            
            temperature
        ]
        df.loc[len(df.index) + 1] = row
        df.to_csv('logprobs_prompts.csv')

        print()
# Out:
# ######################################################################
# Source: reversed_anna_modified_conwell_ullman
# a blanket tied to a spoon
# [None, 3.405046370841077e-06, 0.00013288439742531995, 0.19780489754779018, 0.3137868955724206, 0.0003370599669399436]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAWGiShH1eaabJVPwJDyUPiHAxWe', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.030293273, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.030293273}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.5302932}, {'token': 'A', 'bytes': [65], 'logprob': -7.6709185}, {'token': '"A', 'bytes': [34, 65], 'logprob': -10.186543}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -11.249043}]}, {'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -2.618001e-05, 'top_logprobs': [{'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -2.618001e-05}, {'token': ' blank', 'bytes': [32, 98, 108, 97, 110, 107], 'logprob': -10.593776}, {'token': ' ', 'bytes': [32], 'logprob': -16.062527}, {'token': ' "', 'bytes': [32, 34], 'logprob': -16.187527}, {'token': ' Blank', 'bytes': [32, 66, 108, 97, 110, 107], 'logprob': -16.656277}]}, {'token': ' tied', 'bytes': [32, 116, 105, 101, 100], 'logprob': 0.0, 'top_logprobs': [{'token': ' tied', 'bytes': [32, 116, 105, 101, 100], 'logprob': 0.0}, {'token': '-t', 'bytes': [45, 116], 'logprob': -18.8125}, {'token': ' tired', 'bytes': [32, 116, 105, 114, 101, 100], 'logprob': -18.984375}, {'token': ' to', 'bytes': [32, 116, 111], 'logprob': -19.234375}, {'token': ' ties', 'bytes': [32, 116, 105, 101, 115], 'logprob': -19.609375}]}, {'token': ' to', 'bytes': [32, 116, 111], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': ' to', 'bytes': [32, 116, 111], 'logprob': -3.1281633e-07}, {'token': ' a', 'bytes': [32, 97], 'logprob': -15.640625}, {'token': '-to', 'bytes': [45, 116, 111], 'logprob': -16.921875}, {'token': ' ', 'bytes': [32], 'logprob': -17.609375}, {'token': ' with', 'bytes': [32, 119, 105, 116, 104], 'logprob': -17.78125}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': 0.0, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': 0.0}, {'token': ' ', 'bytes': [32], 'logprob': -18.90625}, {'token': ' an', 'bytes': [32, 97, 110], 'logprob': -19.34375}, {'token': 'a', 'bytes': [97], 'logprob': -19.96875}, {'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -20.90625}]}, {'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -1.9361265e-07, 'top_logprobs': [{'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -1.9361265e-07}, {'token': ' spo', 'bytes': [32, 115, 112, 111], 'logprob': -16.03125}, {'token': ' sp', 'bytes': [32, 115, 112], 'logprob': -18.859375}, {'token': ' Spoon', 'bytes': [32, 83, 112, 111, 111, 110], 'logprob': -18.90625}, {'token': ' ', 'bytes': [32], 'logprob': -19.359375}]}]}, 'message': {'content': 'a blanket tied to a spoon', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594024, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 6, 'prompt_tokens': 37, 'total_tokens': 43}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' blanket', ' tied', ' to', ' a', ' spoon']
# GPT-4 Logprobs: [-0.030293273, -2.618001e-05, 0.0, -3.1281633e-07, 0.0, -1.9361265e-07]
# GPT-4 Probs: [0.9701609698050188, 0.9999738203326934, 1.0, 0.9999996871837189, 1.0, 0.9999998063873687]
# GPT-4 Average Prob: 0.9950223806181334
# Davinci Raw Response: {'id': 'cmpl-9KAWHz58GMmehkU6IigCgXi8YfZap', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 9, 14, 17, 19], 'token_logprobs': [None, -12.590252, -8.926031, -1.6204741, -1.1590412, -7.9952497], 'tokens': ['a', ' blanket', ' tied', ' to', ' a', ' spoon'], 'top_logprobs': None}, 'text': 'a blanket tied to a spoon', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594025, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 6, 'total_tokens': 6}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' blanket', ' tied', ' to', ' a', ' spoon']
# Davinci Logprobs: [None, -12.590252, -8.926031, -1.6204741, -1.1590412, -7.9952497]
# Davinci Probs: [None, 3.405046370841077e-06, 0.00013288439742531995, 0.19780489754779018, 0.3137868955724206, 0.0003370599669399436]
# Davinci Average Prob: 0.10241302850618936
# Babbage Raw Response: {'id': 'cmpl-9KAWHrseiOn2vOZmij64SY4YEQB0S', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 9, 14, 17, 19], 'token_logprobs': [None, -11.456543, -8.736255, -1.7724241, -1.7252462, -8.498213], 'tokens': ['a', ' blanket', ' tied', ' to', ' a', ' spoon'], 'top_logprobs': None}, 'text': 'a blanket tied to a spoon', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594025, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 6, 'total_tokens': 6}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' blanket', ' tied', ' to', ' a', ' spoon']
# Babbage Logprobs: [None, -11.456543, -8.736255, -1.7724241, -1.7252462, -8.498213]
# Babbage Probs: [None, 1.0580022551655034e-05, 0.0001606544135020711, 0.16992058468358734, 0.1781291909670387, 0.00020383229205446084]
# Babbage Average Prob: 0.06968496847574683
#
# a box near a teacup
# [None, 5.397076753083862e-05, 0.00048774603873546476, 0.07027088637577249, 9.06810638934671e-05, 0.07974185294221509, 0.9689955833966035]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAWILpXUFLO0SQgEaFHC6SGqxuzL', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.04003278, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.04003278}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.2431579}, {'token': 'A', 'bytes': [65], 'logprob': -9.383782}, {'token': 'I', 'bytes': [73], 'logprob': -9.993157}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -10.461907}]}, {'token': ' box', 'bytes': [32, 98, 111, 120], 'logprob': -4.604148e-06, 'top_logprobs': [{'token': ' box', 'bytes': [32, 98, 111, 120], 'logprob': -4.604148e-06}, {'token': ' ', 'bytes': [32], 'logprob': -14.437505}, {'token': '-box', 'bytes': [45, 98, 111, 120], 'logprob': -15.117192}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -15.218755}, {'token': ' "', 'bytes': [32, 34], 'logprob': -15.289067}]}, {'token': ' near', 'bytes': [32, 110, 101, 97, 114], 'logprob': -5.3193703e-06, 'top_logprobs': [{'token': ' near', 'bytes': [32, 110, 101, 97, 114], 'logprob': -5.3193703e-06}, {'token': ' ', 'bytes': [32], 'logprob': -14.406256}, {'token': ' next', 'bytes': [32, 110, 101, 120, 116], 'logprob': -14.671881}, {'token': ',', 'bytes': [44], 'logprob': -15.140631}, {'token': ' a', 'bytes': [32, 97], 'logprob': -15.203131}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -5.5122365e-07}, {'token': ' te', 'bytes': [32, 116, 101], 'logprob': -15.359376}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -16.0}, {'token': ' ', 'bytes': [32], 'logprob': -16.75}, {'token': 'a', 'bytes': [97], 'logprob': -16.859375}]}, {'token': ' te', 'bytes': [32, 116, 101], 'logprob': -2.4584822e-06, 'top_logprobs': [{'token': ' te', 'bytes': [32, 116, 101], 'logprob': -2.4584822e-06}, {'token': ' ', 'bytes': [32], 'logprob': -13.859378}, {'token': ' Te', 'bytes': [32, 84, 101], 'logprob': -15.296878}, {'token': '.te', 'bytes': [46, 116, 101], 'logprob': -15.562503}, {'token': ' tea', 'bytes': [32, 116, 101, 97], 'logprob': -15.578128}]}, {'token': 'ac', 'bytes': [97, 99], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': 'ac', 'bytes': [97, 99], 'logprob': -3.1281633e-07}, {'token': 'ap', 'bytes': [97, 112], 'logprob': -16.046875}, {'token': 'acock', 'bytes': [97, 99, 111, 99, 107], 'logprob': -16.21875}, {'token': 'ec', 'bytes': [101, 99], 'logprob': -16.828125}, {'token': 'a', 'bytes': [97], 'logprob': -17.203125}]}, {'token': 'up', 'bytes': [117, 112], 'logprob': -7.600714e-05, 'top_logprobs': [{'token': 'up', 'bytes': [117, 112], 'logprob': -7.600714e-05}, {'token': 'op', 'bytes': [111, 112], 'logprob': -10.031326}, {'token': 'ap', 'bytes': [97, 112], 'logprob': -11.390701}, {'token': 'oup', 'bytes': [111, 117, 112], 'logprob': -11.453201}, {'token': 'ook', 'bytes': [111, 111, 107], 'logprob': -12.921951}]}]}, 'message': {'content': 'a box near a teacup', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594026, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 7, 'prompt_tokens': 38, 'total_tokens': 45}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' box', ' near', ' a', ' te', 'ac', 'up']
# GPT-4 Logprobs: [-0.04003278, -4.604148e-06, -5.3193703e-06, -5.5122365e-07, -2.4584822e-06, -3.1281633e-07, -7.600714e-05]
# GPT-4 Probs: [0.9607579449906999, 0.9999953958625991, 0.9999946806438478, 0.9999994487765019, 0.9999975415208221, 0.9999996871837189, 0.9999239957484695]
# GPT-4 Average Prob: 0.9943812421038085
# Davinci Raw Response: {'id': 'cmpl-9KAWIpxMXq7XbmqcamY37bJEmHM4R', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 5, 10, 12, 15, 17], 'token_logprobs': [None, -9.827068, -7.6257157, -2.6553977, -9.308162, -2.5289607, -0.031495225], 'tokens': ['a', ' box', ' near', ' a', ' te', 'ac', 'up'], 'top_logprobs': None}, 'text': 'a box near a teacup', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594026, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' box', ' near', ' a', ' te', 'ac', 'up']
# Davinci Logprobs: [None, -9.827068, -7.6257157, -2.6553977, -9.308162, -2.5289607, -0.031495225]
# Davinci Probs: [None, 5.397076753083862e-05, 0.00048774603873546476, 0.07027088637577249, 9.06810638934671e-05, 0.07974185294221509, 0.9689955833966035]
# Davinci Average Prob: 0.18660678676412515
# Babbage Raw Response: {'id': 'cmpl-9KAWJ8LlM0jInNkXkgbfHql7q9Zni', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 5, 10, 12, 15, 17], 'token_logprobs': [None, -9.552246, -7.272751, -3.0503893, -9.498296, -1.4063473, -0.013121989], 'tokens': ['a', ' box', ' near', ' a', ' te', 'ac', 'up'], 'top_logprobs': None}, 'text': 'a box near a teacup', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594027, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' box', ' near', ' a', ' te', 'ac', 'up']
# Babbage Logprobs: [None, -9.552246, -7.272751, -3.0503893, -9.498296, -1.4063473, -0.013121989]
# Babbage Probs: [None, 7.104152448363382e-05, 0.0006941996213394025, 0.047340491150138615, 7.497948613806583e-05, 0.2450366960150493, 0.9869637289579974]
# Babbage Average Prob: 0.21336352279252443
#
# an iguana helping a woman
# [None, 3.196336994629125e-05, 0.014865437372373579, 0.6353412136986069, 8.323672452323974e-06, 0.05173996907109214, 0.020781230073409436]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAXEp5VuWaAeicps45jWELChGIPB', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'an', 'bytes': [97, 110], 'logprob': -0.08716105, 'top_logprobs': [{'token': 'an', 'bytes': [97, 110], 'logprob': -0.08716105}, {'token': '"', 'bytes': [34], 'logprob': -2.493411}, {'token': 'An', 'bytes': [65, 110], 'logprob': -7.540286}, {'token': 'I', 'bytes': [73], 'logprob': -8.384036}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -10.102786}]}, {'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -4.3202e-07}, {'token': ' ', 'bytes': [32], 'logprob': -15.890625}, {'token': ' I', 'bytes': [32, 73], 'logprob': -17.046875}, {'token': ' gu', 'bytes': [32, 103, 117], 'logprob': -17.625}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -18.046875}]}, {'token': 'u', 'bytes': [117], 'logprob': 0.0, 'top_logprobs': [{'token': 'u', 'bytes': [117], 'logprob': 0.0}, {'token': 'una', 'bytes': [117, 110, 97], 'logprob': -16.90625}, {'token': 'uan', 'bytes': [117, 97, 110], 'logprob': -18.296875}, {'token': 'a', 'bytes': [97], 'logprob': -18.703125}, {'token': ' u', 'bytes': [32, 117], 'logprob': -20.453125}]}, {'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -7.89631e-07, 'top_logprobs': [{'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -7.89631e-07}, {'token': 'anna', 'bytes': [97, 110, 110, 97], 'logprob': -14.203126}, {'token': 'ANA', 'bytes': [65, 78, 65], 'logprob': -16.828125}, {'token': 'ano', 'bytes': [97, 110, 111], 'logprob': -17.96875}, {'token': 'anda', 'bytes': [97, 110, 100, 97], 'logprob': -18.734375}]}, {'token': ' helping', 'bytes': [32, 104, 101, 108, 112, 105, 110, 103], 'logprob': -0.00012499251, 'top_logprobs': [{'token': ' helping', 'bytes': [32, 104, 101, 108, 112, 105, 110, 103], 'logprob': -0.00012499251}, {'token': ' assisting', 'bytes': [32, 97, 115, 115, 105, 115, 116, 105, 110, 103], 'logprob': -9.375125}, {'token': ' aiding', 'bytes': [32, 97, 105, 100, 105, 110, 103], 'logprob': -12.32825}, {'token': ' working', 'bytes': [32, 119, 111, 114, 107, 105, 110, 103], 'logprob': -12.375125}, {'token': ' fixing', 'bytes': [32, 102, 105, 120, 105, 110, 103], 'logprob': -12.422}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -1.6240566e-06, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -1.6240566e-06}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -13.593752}, {'token': ' ', 'bytes': [32], 'logprob': -16.74219}, {'token': 'a', 'bytes': [97], 'logprob': -17.21094}, {'token': ' to', 'bytes': [32, 116, 111], 'logprob': -17.33594}]}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -4.3202e-07}, {'token': 'woman', 'bytes': [119, 111, 109, 97, 110], 'logprob': -15.53125}, {'token': ' lady', 'bytes': [32, 108, 97, 100, 121], 'logprob': -16.546875}, {'token': ' a', 'bytes': [32, 97], 'logprob': -17.734375}, {'token': ' Woman', 'bytes': [32, 87, 111, 109, 97, 110], 'logprob': -17.890625}]}]}, 'message': {'content': 'an iguana helping a woman', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594084, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 7, 'prompt_tokens': 38, 'total_tokens': 45}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['an', ' ig', 'u', 'ana', ' helping', ' a', ' woman']
# GPT-4 Logprobs: [-0.08716105, -4.3202e-07, 0.0, -7.89631e-07, -0.00012499251, -1.6240566e-06, -4.3202e-07]
# GPT-4 Probs: [0.9165294766742363, 0.9999995679800934, 1.0, 0.9999992103693117, 0.9998750153012383, 0.9999983759447187, 0.9999995679800934]
# GPT-4 Average Prob: 0.9880573163213845
# Davinci Raw Response: {'id': 'cmpl-9KAXF4lr8OKam2TVvGC3hzGjWnkUw', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 2, 5, 6, 9, 17, 19], 'token_logprobs': [None, -10.35092, -4.2087164, -0.45359308, -11.696407, -2.9615247, -3.8737051], 'tokens': ['an', ' ig', 'u', 'ana', ' helping', ' a', ' woman'], 'top_logprobs': None}, 'text': 'an iguana helping a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594085, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['an', ' ig', 'u', 'ana', ' helping', ' a', ' woman']
# Davinci Logprobs: [None, -10.35092, -4.2087164, -0.45359308, -11.696407, -2.9615247, -3.8737051]
# Davinci Probs: [None, 3.196336994629125e-05, 0.014865437372373579, 0.6353412136986069, 8.323672452323974e-06, 0.05173996907109214, 0.020781230073409436]
# Davinci Average Prob: 0.12046135620964676
# Babbage Raw Response: {'id': 'cmpl-9KAXG286pm0fI2sd6lVanYTNYfrF7', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 2, 5, 6, 9, 17, 19], 'token_logprobs': [None, -10.309097, -3.2607694, -0.8769613, -10.999703, -3.2294626, -4.1290007], 'tokens': ['an', ' ig', 'u', 'ana', ' helping', ' a', ' woman'], 'top_logprobs': None}, 'text': 'an iguana helping a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594086, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['an', ' ig', 'u', 'ana', ' helping', ' a', ' woman']
# Babbage Logprobs: [None, -10.309097, -3.2607694, -0.8769613, -10.999703, -3.2294626, -4.1290007]
# Babbage Probs: [None, 3.332852236869055e-05, 0.03835887334371588, 0.4160452294464827, 1.6706661932073453e-05, 0.03957876270134926, 0.016098958476256708]
# Babbage Average Prob: 0.08502197652535089
#
# a robot hindering a woman
# [None, 1.2467316723189192e-05, 6.917113497459227e-06, 0.01039126219017971, 0.04532779311867427, 0.002355699424657361]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAXGkoWaB17iJCZImql06vtexeA5', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.14284454, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.14284454}, {'token': '"a', 'bytes': [34, 97], 'logprob': -2.0178444}, {'token': 'A', 'bytes': [65], 'logprob': -9.377219}, {'token': 'I', 'bytes': [73], 'logprob': -10.674094}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -10.939719}]}, {'token': ' robot', 'bytes': [32, 114, 111, 98, 111, 116], 'logprob': -3.070975e-05, 'top_logprobs': [{'token': ' robot', 'bytes': [32, 114, 111, 98, 111, 116], 'logprob': -3.070975e-05}, {'token': ' bot', 'bytes': [32, 98, 111, 116], 'logprob': -12.0312805}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -12.1875305}, {'token': ' ', 'bytes': [32], 'logprob': -12.9062805}, {'token': ' ro', 'bytes': [32, 114, 111], 'logprob': -13.0781555}]}, {'token': ' hind', 'bytes': [32, 104, 105, 110, 100], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' hind', 'bytes': [32, 104, 105, 110, 100], 'logprob': -5.5122365e-07}, {'token': ' hinder', 'bytes': [32, 104, 105, 110, 100, 101, 114], 'logprob': -15.046876}, {'token': ' is', 'bytes': [32, 105, 115], 'logprob': -16.359375}, {'token': 'hind', 'bytes': [104, 105, 110, 100], 'logprob': -17.03125}, {'token': ' ', 'bytes': [32], 'logprob': -17.859375}]}, {'token': 'ering', 'bytes': [101, 114, 105, 110, 103], 'logprob': 0.0, 'top_logprobs': [{'token': 'ering', 'bytes': [101, 114, 105, 110, 103], 'logprob': 0.0}, {'token': 'erring', 'bytes': [101, 114, 114, 105, 110, 103], 'logprob': -21.78125}, {'token': 'ERING', 'bytes': [69, 82, 73, 78, 71], 'logprob': -23.765625}, {'token': 'uring', 'bytes': [117, 114, 105, 110, 103], 'logprob': -24.984375}, {'token': 'ring', 'bytes': [114, 105, 110, 103], 'logprob': -25.171875}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -4.00813e-06, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -4.00813e-06}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -12.578129}, {'token': ' ', 'bytes': [32], 'logprob': -16.171879}, {'token': ' an', 'bytes': [32, 97, 110], 'logprob': -16.296879}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -16.765629}]}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': 0.0, 'top_logprobs': [{'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': 0.0}, {'token': 'woman', 'bytes': [119, 111, 109, 97, 110], 'logprob': -17.953125}, {'token': ' Woman', 'bytes': [32, 87, 111, 109, 97, 110], 'logprob': -18.640625}, {'token': ' women', 'bytes': [32, 119, 111, 109, 101, 110], 'logprob': -19.234375}, {'token': ' wom', 'bytes': [32, 119, 111, 109], 'logprob': -19.34375}]}]}, 'message': {'content': 'a robot hindering a woman', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594086, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 6, 'prompt_tokens': 37, 'total_tokens': 43}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' robot', ' hind', 'ering', ' a', ' woman']
# GPT-4 Logprobs: [-0.14284454, -3.070975e-05, -5.5122365e-07, 0.0, -4.00813e-06, 0.0]
# GPT-4 Probs: [0.8668888249573568, 0.9999692907215395, 0.9999994487765019, 1.0, 0.9999959918780326, 1.0]
# GPT-4 Average Prob: 0.9778089260555718
# Davinci Raw Response: {'id': 'cmpl-9KAXH7f07Ixnh63L14VSmcECwLHef', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 12, 17, 19], 'token_logprobs': [None, -11.2924, -11.881512, -4.56679, -3.0938349, -6.0509176], 'tokens': ['a', ' robot', ' hind', 'ering', ' a', ' woman'], 'top_logprobs': None}, 'text': 'a robot hindering a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594087, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 6, 'total_tokens': 6}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' robot', ' hind', 'ering', ' a', ' woman']
# Davinci Logprobs: [None, -11.2924, -11.881512, -4.56679, -3.0938349, -6.0509176]
# Davinci Probs: [None, 1.2467316723189192e-05, 6.917113497459227e-06, 0.01039126219017971, 0.04532779311867427, 0.002355699424657361]
# Davinci Average Prob: 0.011618827832746398
# Babbage Raw Response: {'id': 'cmpl-9KAXHxZnq3UMeSeF7YgWqIEgllBsG', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 12, 17, 19], 'token_logprobs': [None, -10.614746, -12.36051, -3.713316, -3.2160387, -4.8329983], 'tokens': ['a', ' robot', ' hind', 'ering', ' a', ' woman'], 'top_logprobs': None}, 'text': 'a robot hindering a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594087, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 6, 'total_tokens': 6}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' robot', ' hind', 'ering', ' a', ' woman']
# Babbage Logprobs: [None, -10.614746, -12.36051, -3.713316, -3.2160387, -4.8329983]
# Babbage Probs: [None, 2.4551293910514574e-05, 4.284485856191492e-06, 0.02439649023151671, 0.040113646132631804, 0.007962611142018362]
# Babbage Average Prob: 0.014500316657186716
#
# a monkey pulling a woman
# [None, 4.04359261504464e-06, 0.00011707966001663371, 0.28991079696256217, 0.008017596422217466]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAYDGRhC9KOf1O4n3aXepUgZLpK8', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.35801193, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.35801193}, {'token': '"a', 'bytes': [34, 97], 'logprob': -1.201762}, {'token': 'A', 'bytes': [65], 'logprob': -8.748637}, {'token': 'I', 'bytes': [73], 'logprob': -10.373637}, {'token': '"A', 'bytes': [34, 65], 'logprob': -10.420512}]}, {'token': ' monkey', 'bytes': [32, 109, 111, 110, 107, 101, 121], 'logprob': -6.0345924e-06, 'top_logprobs': [{'token': ' monkey', 'bytes': [32, 109, 111, 110, 107, 101, 121], 'logprob': -6.0345924e-06}, {'token': ' monk', 'bytes': [32, 109, 111, 110, 107], 'logprob': -13.796881}, {'token': ' mon', 'bytes': [32, 109, 111, 110], 'logprob': -13.984381}, {'token': ' ', 'bytes': [32], 'logprob': -14.234381}, {'token': ' Monkey', 'bytes': [32, 77, 111, 110, 107, 101, 121], 'logprob': -14.625006}]}, {'token': ' pulling', 'bytes': [32, 112, 117, 108, 108, 105, 110, 103], 'logprob': -7.89631e-07, 'top_logprobs': [{'token': ' pulling', 'bytes': [32, 112, 117, 108, 108, 105, 110, 103], 'logprob': -7.89631e-07}, {'token': ' pul', 'bytes': [32, 112, 117, 108], 'logprob': -16.0}, {'token': ' dragging', 'bytes': [32, 100, 114, 97, 103, 103, 105, 110, 103], 'logprob': -16.015625}, {'token': ' drawing', 'bytes': [32, 100, 114, 97, 119, 105, 110, 103], 'logprob': -16.671875}, {'token': ',', 'bytes': [44], 'logprob': -16.703125}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -9.0883464e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -9.0883464e-07}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -14.203126}, {'token': ' ', 'bytes': [32], 'logprob': -17.015625}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -17.882812}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -18.070312}]}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -8.061054e-06, 'top_logprobs': [{'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -8.061054e-06}, {'token': ' women', 'bytes': [32, 119, 111, 109, 101, 110], 'logprob': -12.484383}, {'token': ' wom', 'bytes': [32, 119, 111, 109], 'logprob': -13.546883}, {'token': 'woman', 'bytes': [119, 111, 109, 97, 110], 'logprob': -13.718758}, {'token': ' ', 'bytes': [32], 'logprob': -14.234383}]}]}, 'message': {'content': 'a monkey pulling a woman', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594145, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'low'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' monkey', ' pulling', ' a', ' woman']
# GPT-4 Logprobs: [-0.35801193, -6.0345924e-06, -7.89631e-07, -9.0883464e-07, -8.061054e-06]
# GPT-4 Probs: [0.6990647351144884, 0.9999939654258081, 0.9999992103693117, 0.999999091165773, 0.9999919389784903]
# GPT-4 Average Prob: 0.9398097882107743
# Davinci Raw Response: {'id': 'cmpl-9KAYErxjCNIIT5l0KstPZ7di098j0', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 8, 16, 18], 'token_logprobs': [None, -12.418377, -9.052656, -1.238182, -4.8261166], 'tokens': ['a', ' monkey', ' pulling', ' a', ' woman'], 'top_logprobs': None}, 'text': 'a monkey pulling a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594146, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' monkey', ' pulling', ' a', ' woman']
# Davinci Logprobs: [None, -12.418377, -9.052656, -1.238182, -4.8261166]
# Davinci Probs: [None, 4.04359261504464e-06, 0.00011707966001663371, 0.28991079696256217, 0.008017596422217466]
# Davinci Average Prob: 0.07451237915935283
# Babbage Raw Response: {'id': 'cmpl-9KAYEWSEByQRW8tWaLyxIJC672spr', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 8, 16, 18], 'token_logprobs': [None, -11.628418, -9.1906185, -1.6022838, -5.484847], 'tokens': ['a', ' monkey', ' pulling', ' a', ' woman'], 'top_logprobs': None}, 'text': 'a monkey pulling a woman', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594146, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' monkey', ' pulling', ' a', ' woman']
# Babbage Logprobs: [None, -11.628418, -9.1906185, -1.6022838, -5.484847]
# Babbage Probs: [None, 8.909272229574495e-06, 0.00010199176328994393, 0.20143595284638446, 0.004149169853709384]
# Babbage Average Prob: 0.051424005933903345
#
# a robot pulling an iguana
# [None, 1.2467316723189192e-05, 1.7410867112439252e-05, 0.02066755912644244, 0.00031003573280962647, 0.4257052813299769, 0.9938355262161684]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAYE5waloKfdtpS6AZNNj3fH8SVA', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.027687276, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.027687276}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.6058123}, {'token': 'A', 'bytes': [65], 'logprob': -9.355812}, {'token': 'I', 'bytes': [73], 'logprob': -11.074562}, {'token': '"', 'bytes': [34], 'logprob': -11.543312}]}, {'token': ' robot', 'bytes': [32, 114, 111, 98, 111, 116], 'logprob': -6.749814e-06, 'top_logprobs': [{'token': ' robot', 'bytes': [32, 114, 111, 98, 111, 116], 'logprob': -6.749814e-06}, {'token': ' bot', 'bytes': [32, 98, 111, 116], 'logprob': -13.468757}, {'token': ' ro', 'bytes': [32, 114, 111], 'logprob': -13.671882}, {'token': ' ', 'bytes': [32], 'logprob': -13.718757}, {'token': ' string', 'bytes': [32, 115, 116, 114, 105, 110, 103], 'logprob': -14.843757}]}, {'token': ' pulling', 'bytes': [32, 112, 117, 108, 108, 105, 110, 103], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' pulling', 'bytes': [32, 112, 117, 108, 108, 105, 110, 103], 'logprob': -5.5122365e-07}, {'token': ' pushing', 'bytes': [32, 112, 117, 115, 104, 105, 110, 103], 'logprob': -15.906251}, {'token': ' pul', 'bytes': [32, 112, 117, 108], 'logprob': -16.28125}, {'token': ',', 'bytes': [44], 'logprob': -17.015625}, {'token': ' dragging', 'bytes': [32, 100, 114, 97, 103, 103, 105, 110, 103], 'logprob': -17.0625}]}, {'token': ' an', 'bytes': [32, 97, 110], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' an', 'bytes': [32, 97, 110], 'logprob': -5.5122365e-07}, {'token': ' a', 'bytes': [32, 97], 'logprob': -15.390626}, {'token': ' and', 'bytes': [32, 97, 110, 100], 'logprob': -15.828126}, {'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -16.890625}, {'token': ' ', 'bytes': [32], 'logprob': -17.25}]}, {'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -4.3202e-07}, {'token': ' Ig', 'bytes': [32, 73, 103], 'logprob': -15.1875}, {'token': 'ig', 'bytes': [105, 103], 'logprob': -16.0}, {'token': ' ', 'bytes': [32], 'logprob': -18.390625}, {'token': ' I', 'bytes': [32, 73], 'logprob': -18.6875}]}, {'token': 'u', 'bytes': [117], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': 'u', 'bytes': [117], 'logprob': -3.1281633e-07}, {'token': 'loo', 'bytes': [108, 111, 111], 'logprob': -15.09375}, {'token': 'una', 'bytes': [117, 110, 97], 'logprob': -17.03125}, {'token': 'ua', 'bytes': [117, 97], 'logprob': -17.328125}, {'token': 'uan', 'bytes': [117, 97, 110], 'logprob': -17.828125}]}, {'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -5.3193703e-06, 'top_logprobs': [{'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -5.3193703e-06}, {'token': 'anna', 'bytes': [97, 110, 110, 97], 'logprob': -12.359381}, {'token': 'ano', 'bytes': [97, 110, 111], 'logprob': -14.390631}, {'token': 'anta', 'bytes': [97, 110, 116, 97], 'logprob': -15.765631}, {'token': 'ANA', 'bytes': [65, 78, 65], 'logprob': -16.89063}]}]}, 'message': {'content': 'a robot pulling an iguana', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594146, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 7, 'prompt_tokens': 38, 'total_tokens': 45}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' robot', ' pulling', ' an', ' ig', 'u', 'ana']
# GPT-4 Logprobs: [-0.027687276, -6.749814e-06, -5.5122365e-07, -5.5122365e-07, -4.3202e-07, -3.1281633e-07, -5.3193703e-06]
# GPT-4 Probs: [0.9726925035338156, 0.9999932502087799, 0.9999994487765019, 0.9999994487765019, 0.9999995679800934, 0.9999996871837189, 0.9999946806438478]
# GPT-4 Average Prob: 0.9960969410147513
# Davinci Raw Response: {'id': 'cmpl-9KAYFuwNTPXH7EafTVTIizJTdDZ2M', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 15, 18, 21, 22], 'token_logprobs': [None, -11.2924, -10.958416, -3.87919, -8.078823, -0.854008, -0.0061835526], 'tokens': ['a', ' robot', ' pulling', ' an', ' ig', 'u', 'ana'], 'top_logprobs': None}, 'text': 'a robot pulling an iguana', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594147, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' robot', ' pulling', ' an', ' ig', 'u', 'ana']
# Davinci Logprobs: [None, -11.2924, -10.958416, -3.87919, -8.078823, -0.854008, -0.0061835526]
# Davinci Probs: [None, 1.2467316723189192e-05, 1.7410867112439252e-05, 0.02066755912644244, 0.00031003573280962647, 0.4257052813299769, 0.9938355262161684]
# Davinci Average Prob: 0.24009138009820552
# Babbage Raw Response: {'id': 'cmpl-9KAYF6lStfG8j8RKblekWoCIm0RiH', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 15, 18, 21, 22], 'token_logprobs': [None, -10.614746, -11.2921505, -3.513886, -7.6352205, -1.1576515, -0.0019612247], 'tokens': ['a', ' robot', ' pulling', ' an', ' ig', 'u', 'ana'], 'top_logprobs': None}, 'text': 'a robot pulling an iguana', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594147, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' robot', ' pulling', ' an', ' ig', 'u', 'ana']
# Babbage Logprobs: [None, -10.614746, -11.2921505, -3.513886, -7.6352205, -1.1576515, -0.0019612247]
# Babbage Probs: [None, 2.4551293910514574e-05, 1.2470427706790704e-05, 0.0297809604718968, 0.0004831320723363022, 0.31422326836460296, 0.9980406972445016]
# Babbage Average Prob: 0.22376084664582585
#
# a bowl covering a blanket
# [None, 2.7643056021483536e-05, 4.939906801704919e-05, 0.09555388020145258, 0.00039796181479848824]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAZCECinQctUebtLnSxgXzIqwmou', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.13871816, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.13871816}, {'token': '"a', 'bytes': [34, 97], 'logprob': -2.0449681}, {'token': 'A', 'bytes': [65], 'logprob': -9.341844}, {'token': 'I', 'bytes': [73], 'logprob': -10.810594}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -11.623094}]}, {'token': ' bowl', 'bytes': [32, 98, 111, 119, 108], 'logprob': -5.6769813e-06, 'top_logprobs': [{'token': ' bowl', 'bytes': [32, 98, 111, 119, 108], 'logprob': -5.6769813e-06}, {'token': ' bow', 'bytes': [32, 98, 111, 119], 'logprob': -13.671881}, {'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -13.984381}, {'token': ' Bowl', 'bytes': [32, 66, 111, 119, 108], 'logprob': -14.078131}, {'token': ' bowel', 'bytes': [32, 98, 111, 119, 101, 108], 'logprob': -14.484381}]}, {'token': ' covering', 'bytes': [32, 99, 111, 118, 101, 114, 105, 110, 103], 'logprob': -9.0883464e-07, 'top_logprobs': [{'token': ' covering', 'bytes': [32, 99, 111, 118, 101, 114, 105, 110, 103], 'logprob': -9.0883464e-07}, {'token': ',', 'bytes': [44], 'logprob': -15.093751}, {'token': 'covering', 'bytes': [99, 111, 118, 101, 114, 105, 110, 103], 'logprob': -15.859376}, {'token': ' is', 'bytes': [32, 105, 115], 'logprob': -16.53125}, {'token': ' ', 'bytes': [32], 'logprob': -16.734375}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -4.3202e-07}, {'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -16.25}, {'token': ' ', 'bytes': [32], 'logprob': -16.703125}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -16.75}, {'token': 'a', 'bytes': [97], 'logprob': -18.28125}]}, {'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -8.657073e-06, 'top_logprobs': [{'token': ' blanket', 'bytes': [32, 98, 108, 97, 110, 107, 101, 116], 'logprob': -8.657073e-06}, {'token': ' blank', 'bytes': [32, 98, 108, 97, 110, 107], 'logprob': -12.328134}, {'token': ' basket', 'bytes': [32, 98, 97, 115, 107, 101, 116], 'logprob': -12.921884}, {'token': '.blank', 'bytes': [46, 98, 108, 97, 110, 107], 'logprob': -14.296884}, {'token': ' ', 'bytes': [32], 'logprob': -15.843759}]}]}, 'message': {'content': 'a bowl covering a blanket', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594206, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' bowl', ' covering', ' a', ' blanket']
# GPT-4 Logprobs: [-0.13871816, -5.6769813e-06, -9.0883464e-07, -4.3202e-07, -8.657073e-06]
# GPT-4 Probs: [0.8704733280917929, 0.9999943230348141, 0.999999091165773, 0.9999995679800934, 0.9999913429644723]
# GPT-4 Average Prob: 0.9740915306473891
# Davinci Raw Response: {'id': 'cmpl-9KAZDPpoKQu1UzEELteyzZwSIwMbw', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 6, 15, 17], 'token_logprobs': [None, -10.496136, -9.915579, -2.348065, -7.8291545], 'tokens': ['a', ' bowl', ' covering', ' a', ' blanket'], 'top_logprobs': None}, 'text': 'a bowl covering a blanket', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714594207, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' bowl', ' covering', ' a', ' blanket']
# Davinci Logprobs: [None, -10.496136, -9.915579, -2.348065, -7.8291545]
# Davinci Probs: [None, 2.7643056021483536e-05, 4.939906801704919e-05, 0.09555388020145258, 0.00039796181479848824]
# Davinci Average Prob: 0.024007221035072402
# ...
# Babbage Tokens: ['a', ' te', 'ac', 'up', ' pushing', ' a', ' man']
# Babbage Logprobs: [None, -7.5654297, -6.744443, -0.29875097, -13.137817, -2.2850142, -6.7550545]
# Babbage Probs: [None, 0.0005180547118242447, 0.0011774043109050627, 0.7417441029709032, 1.9693303438152302e-06, 0.10177261692486264, 0.0011649763413788422]
# Babbage Average Prob: 0.14106318743170296
#
# a spoon tied to a teacup
# [None, 7.372224983284195e-06, 2.1997450449074538e-05, 0.5209337524083922, 0.5106927916881564, 7.98148484512396e-05, 0.15281118571316146, 0.9828314632093675]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAmy4cgRA9hqOUKXZPYv5qLV1HHg', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.044117846, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.044117846}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.153493}, {'token': 'A', 'bytes': [65], 'logprob': -7.887868}, {'token': '"A', 'bytes': [34, 65], 'logprob': -10.372243}, {'token': 'I', 'bytes': [73], 'logprob': -10.840993}]}, {'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -4.3202e-07}, {'token': ' ', 'bytes': [32], 'logprob': -16.171875}, {'token': ' spo', 'bytes': [32, 115, 112, 111], 'logprob': -16.265625}, {'token': ' sp', 'bytes': [32, 115, 112], 'logprob': -16.625}, {'token': ' string', 'bytes': [32, 115, 116, 114, 105, 110, 103], 'logprob': -16.90625}]}, {'token': ' tied', 'bytes': [32, 116, 105, 101, 100], 'logprob': -6.704273e-07, 'top_logprobs': [{'token': ' tied', 'bytes': [32, 116, 105, 101, 100], 'logprob': -6.704273e-07}, {'token': ' tired', 'bytes': [32, 116, 105, 114, 101, 100], 'logprob': -15.515626}, {'token': '-t', 'bytes': [45, 116], 'logprob': -15.765626}, {'token': ' is', 'bytes': [32, 105, 115], 'logprob': -16.453125}, {'token': ' to', 'bytes': [32, 116, 111], 'logprob': -17.453125}]}, {'token': ' to', 'bytes': [32, 116, 111], 'logprob': -1.2664457e-06, 'top_logprobs': [{'token': ' to', 'bytes': [32, 116, 111], 'logprob': -1.2664457e-06}, {'token': ' a', 'bytes': [32, 97], 'logprob': -14.078126}, {'token': ' ', 'bytes': [32], 'logprob': -16.265627}, {'token': ' with', 'bytes': [32, 119, 105, 116, 104], 'logprob': -16.734377}, {'token': '-to', 'bytes': [45, 116, 111], 'logprob': -17.328127}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -1.0280384e-06, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -1.0280384e-06}, {'token': ' te', 'bytes': [32, 116, 101], 'logprob': -14.203126}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -16.015627}, {'token': 'a', 'bytes': [97], 'logprob': -16.984377}, {'token': ' ', 'bytes': [32], 'logprob': -17.125002}]}, {'token': ' te', 'bytes': [32, 116, 101], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': ' te', 'bytes': [32, 116, 101], 'logprob': -3.1281633e-07}, {'token': ' tea', 'bytes': [32, 116, 101, 97], 'logprob': -16.609375}, {'token': ' ', 'bytes': [32], 'logprob': -17.140625}, {'token': '\n', 'bytes': [10], 'logprob': -17.671875}, {'token': ' teaspoon', 'bytes': [32, 116, 101, 97, 115, 112, 111, 111, 110], 'logprob': -18.171875}]}, {'token': 'ac', 'bytes': [97, 99], 'logprob': -1.9361265e-07, 'top_logprobs': [{'token': 'ac', 'bytes': [97, 99], 'logprob': -1.9361265e-07}, {'token': 'ak', 'bytes': [97, 107], 'logprob': -17.59375}, {'token': 'apot', 'bytes': [97, 112, 111, 116], 'logprob': -17.890625}, {'token': 'ap', 'bytes': [97, 112], 'logprob': -17.921875}, {'token': 'acock', 'bytes': [97, 99, 111, 99, 107], 'logprob': -18.015625}]}, {'token': 'up', 'bytes': [117, 112], 'logprob': -0.00013047588, 'top_logprobs': [{'token': 'up', 'bytes': [117, 112], 'logprob': -0.00013047588}, {'token': 'op', 'bytes': [111, 112], 'logprob': -9.125131}, {'token': 'oup', 'bytes': [111, 117, 112], 'logprob': -11.406381}, {'token': 'ook', 'bytes': [111, 111, 107], 'logprob': -11.797006}, {'token': 'ap', 'bytes': [97, 112], 'logprob': -13.531381}]}]}, 'message': {'content': 'a spoon tied to a teacup', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595060, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 8, 'prompt_tokens': 39, 'tot ...
# GPT-4 Tokens: ['a', ' spoon', ' tied', ' to', ' a', ' te', 'ac', 'up']
# GPT-4 Logprobs: [-0.044117846, -4.3202e-07, -6.704273e-07, -1.2664457e-06, -1.0280384e-06, -3.1281633e-07, -1.9361265e-07, -0.00013047588]
# GPT-4 Probs: [0.9568411909216483, 0.9999995679800934, 0.9999993295729247, 0.9999987335551019, 0.9999989719621284, 0.9999996871837189, 0.9999998063873687, 0.9998695326316075]
# GPT-4 Average Prob: 0.994588352524324
# Davinci Raw Response: {'id': 'cmpl-9KAmz2SoVLa5EdKebbujFTZfdbmUo', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 12, 15, 17, 20, 22], 'token_logprobs': [None, -11.817791, -10.724584, -0.6521324, -0.67198706, -9.435801, -1.8785522, -0.017317625], 'tokens': ['a', ' spoon', ' tied', ' to', ' a', ' te', 'ac', 'up'], 'top_logprobs': None}, 'text': 'a spoon tied to a teacup', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595061, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 8, 'total_tokens': 8}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' spoon', ' tied', ' to', ' a', ' te', 'ac', 'up']
# Davinci Logprobs: [None, -11.817791, -10.724584, -0.6521324, -0.67198706, -9.435801, -1.8785522, -0.017317625]
# Davinci Probs: [None, 7.372224983284195e-06, 2.1997450449074538e-05, 0.5209337524083922, 0.5106927916881564, 7.98148484512396e-05, 0.15281118571316146, 0.9828314632093675]
# Davinci Average Prob: 0.30962548250613736
# Babbage Raw Response: {'id': 'cmpl-9KAn0zjlnDpqUfwKrll3gvEIGGEmS', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 12, 15, 17, 20, 22], 'token_logprobs': [None, -11.169434, -10.952009, -0.60070205, -1.046854, -7.7163963, -2.0954242, -0.019217364], 'tokens': ['a', ' spoon', ' tied', ' to', ' a', ' te', 'ac', 'up'], 'top_logprobs': None}, 'text': 'a spoon tied to a teacup', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595062, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 8, 'total_tokens': 8}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' spoon', ' tied', ' to', ' a', ' te', 'ac', 'up']
# Babbage Logprobs: [None, -11.169434, -10.952009, -0.60070205, -1.046854, -7.7163963, -2.0954242, -0.019217364]
# Babbage Probs: [None, 1.4098614892217333e-05, 1.752277665743567e-05, 0.5484264781008107, 0.35104038680952926, 0.00044546302995836766, 0.12301804832802103, 0.980966112349176]
# Babbage Average Prob: 0.2862754442870064
#
# a spoon hitting an iguana
# [None, 7.372224983284195e-06, 3.882780644710904e-06, 0.014034832551775874, 2.2685445647762068e-05, 0.27863081977808396, 0.9899080420360729]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KAn0zeKJcFhJPiiUTl6otu4hA1Ac', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.019537603, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.019537603}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.9570377}, {'token': 'A', 'bytes': [65], 'logprob': -8.816413}, {'token': 'I', 'bytes': [73], 'logprob': -10.019538}, {'token': '"A', 'bytes': [34, 65], 'logprob': -11.644538}]}, {'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -1.0280384e-06, 'top_logprobs': [{'token': ' spoon', 'bytes': [32, 115, 112, 111, 111, 110], 'logprob': -1.0280384e-06}, {'token': ' ', 'bytes': [32], 'logprob': -15.171876}, {'token': ' spo', 'bytes': [32, 115, 112, 111], 'logprob': -15.453126}, {'token': ' Spoon', 'bytes': [32, 83, 112, 111, 111, 110], 'logprob': -15.859376}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -16.953127}]}, {'token': ' hitting', 'bytes': [32, 104, 105, 116, 116, 105, 110, 103], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' hitting', 'bytes': [32, 104, 105, 116, 116, 105, 110, 103], 'logprob': -5.5122365e-07}, {'token': ' ', 'bytes': [32], 'logprob': -16.21875}, {'token': ' is', 'bytes': [32, 105, 115], 'logprob': -16.453125}, {'token': 'ing', 'bytes': [105, 110, 103], 'logprob': -16.46875}, {'token': ' striking', 'bytes': [32, 115, 116, 114, 105, 107, 105, 110, 103], 'logprob': -16.46875}]}, {'token': ' an', 'bytes': [32, 97, 110], 'logprob': -9.0883464e-07, 'top_logprobs': [{'token': ' an', 'bytes': [32, 97, 110], 'logprob': -9.0883464e-07}, {'token': ' a', 'bytes': [32, 97], 'logprob': -14.859376}, {'token': ' and', 'bytes': [32, 97, 110, 100], 'logprob': -15.531251}, {'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -15.703126}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -16.453125}]}, {'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -9.133887e-06, 'top_logprobs': [{'token': ' ig', 'bytes': [32, 105, 103], 'logprob': -9.133887e-06}, {'token': ' ing', 'bytes': [32, 105, 110, 103], 'logprob': -12.015635}, {'token': ' Ig', 'bytes': [32, 73, 103], 'logprob': -13.453135}, {'token': ' ', 'bytes': [32], 'logprob': -13.93751}, {'token': ' ign', 'bytes': [32, 105, 103, 110], 'logprob': -15.484385}]}, {'token': 'u', 'bytes': [117], 'logprob': -6.704273e-07, 'top_logprobs': [{'token': 'u', 'bytes': [117], 'logprob': -6.704273e-07}, {'token': 'ua', 'bytes': [117, 97], 'logprob': -14.671876}, {'token': 'uan', 'bytes': [117, 97, 110], 'logprob': -16.21875}, {'token': 'una', 'bytes': [117, 110, 97], 'logprob': -16.359375}, {'token': 'loo', 'bytes': [108, 111, 111], 'logprob': -19.328125}]}, {'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -6.511407e-06, 'top_logprobs': [{'token': 'ana', 'bytes': [97, 110, 97], 'logprob': -6.511407e-06}, {'token': 'anna', 'bytes': [97, 110, 110, 97], 'logprob': -12.156257}, {'token': 'ano', 'bytes': [97, 110, 111], 'logprob': -14.828132}, {'token': 'anta', 'bytes': [97, 110, 116, 97], 'logprob': -14.968757}, {'token': 'anda', 'bytes': [97, 110, 100, 97], 'logprob': -16.45313}]}]}, 'message': {'content': 'a spoon hitting an iguana', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595062, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 7, 'prompt_tokens': 38, 'total_tokens': 45}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' spoon', ' hitting', ' an', ' ig', 'u', 'ana']
# GPT-4 Logprobs: [-0.019537603, -1.0280384e-06, -5.5122365e-07, -9.0883464e-07, -9.133887e-06, -6.704273e-07, -6.511407e-06]
# GPT-4 Probs: [0.9806520190374717, 0.9999989719621284, 0.9999994487765019, 0.999999091165773, 0.9999908661547138, 0.9999993295729247, 0.9999934886141991]
# GPT-4 Average Prob: 0.9972333164691017
# Davinci Raw Response: {'id': 'cmpl-9KAn1RhplHtagsEgRBRUZVslwOOmC', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 15, 18, 21, 22], 'token_logprobs': [None, -11.817791, -12.458959, -4.266213, -10.693787, -1.2778676, -0.010143227], 'tokens': ['a', ' spoon', ' hitting', ' an', ' ig', 'u', 'ana'], 'top_logprobs': None}, 'text': 'a spoon hitting an iguana', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595063, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' spoon', ' hitting', ' an', ' ig', 'u', 'ana']
# Davinci Logprobs: [None, -11.817791, -12.458959, -4.266213, -10.693787, -1.2778676, -0.010143227]
# Davinci Probs: [None, 7.372224983284195e-06, 3.882780644710904e-06, 0.014034832551775874, 2.2685445647762068e-05, 0.27863081977808396, 0.9899080420360729]
# Davinci Average Prob: 0.2137679391362014
# Babbage Raw Response: {'id': 'cmpl-9KAn12R8MPNVrLFFYgTRf5qVQJ0R4', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 15, 18, 21, 22], 'token_logprobs': [None, -11.169434, -11.7233715, -5.024222, -8.827431, -1.2692474, -0.00067609677], 'tokens': ['a', ' spoon', ' hitting', ' an', ' ig', 'u', 'ana'], 'top_logprobs': None}, 'text': 'a spoon hitting an iguana', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714595063, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 7, 'total_tokens': 7}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' spoon', ' hitting', ' an', ' ig', 'u', 'ana']
# Babbage Logprobs: [None, -11.169434, -11.7233715, -5.024222, -8.827431, -1.2692474, -0.00067609677]
# Babbage Probs: [None, 1.4098614892217333e-05, 8.102227776216684e-06, 0.006576701178576623, 0.00014665451139600093, 0.28104305520935047, 0.9993241317319218]
# Babbage Average Prob: 0.21451879057898557

# %% [markdown]
# ## Misc. code

# %%
gpt35_raw_response
# Out:
# {'id': 'cmpl-9Jr0vyudFY9Ay20RxE9K6K5HhhecB',
#  'choices': [{'finish_reason': 'length',
#    'index': 0,
#    'logprobs': None,
#    'text': 'a man eating a cucumber\n\nA man eating a cucumber would look like a person holding a long, green vegetable in their hand and taking bites out of it. They may be sitting or standing, and their facial expression could range from neutral to satisfied, depending on how much they',
#    'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'},
#     'self_harm': {'filtered': False, 'severity': 'safe'},
#     'sexual': {'filtered': False, 'severity': 'safe'},
#     'violence': {'filtered': False, 'severity': 'safe'}}}],
#  'created': 1714519045,
#  'model': 'gpt-35-turbo-instruct',
#  'object': 'text_completion',
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 50, 'prompt_tokens': 5, 'total_tokens': 55},
#  'prompt_filter_results': [{'prompt_index': 0,
#    'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'},
#     'self_harm': {'filtered': False, 'severity': 'safe'},
#     'sexual': {'filtered': False, 'severity': 'safe'},
#     'violence': {'filtered': False, 'severity': 'safe'}}}]}

# %%
# combine csv files
df = pd.concat([pd.read_csv('subset1_logprobs_prompts.csv'), pd.read_csv('subset2_logprobs_prompts.csv')])

# %%
df = df.reset_index()
print(df.columns)
print(df)
# df.to_csv('logprobs_prompts.csv')
# Out:
# Index(['index', 'Unnamed: 0', 'source', 'prompt', 'gpt4_raw_response',
#        'davinci_raw_response', 'babbage_raw_response', 'gpt4_tokens',
#        'davinci_tokens', 'babbage_tokens', 'gpt4_logprobs', 'davinci_logprobs',
#        'babbage_logprobs', 'gpt4_probs', 'davinci_probs', 'babbage_probs',
#        'gpt4_avg_prob', 'davinci_avg_prob', 'babbage_avg_prob', 'temperature'],
#       dtype='object')
#      index  Unnamed: 0                                 source  \
# 0        0           1           anna_modified_conwell_ullman
# 1        1           2           anna_modified_conwell_ullman
# 2        2           3           anna_modified_conwell_ullman
# 3        3           4           anna_modified_conwell_ullman
# 4        4           5           anna_modified_conwell_ullman
# ..     ...         ...                                    ...
# 145     31          32  reversed_anna_modified_conwell_ullman
# 146     32          33  reversed_anna_modified_conwell_ullman
# 147     33          34  reversed_anna_modified_conwell_ullman
# 148     34          35  reversed_anna_modified_conwell_ullman
# 149     35          36  reversed_anna_modified_conwell_ullman
#
#                             prompt  \
# 0              a blanket in a bowl
# 1          a blanket near a teacup
# 2    a bowl hanging over a blanket
# 3        a box hanging over a bowl
# 4                  a box in a bowl
# ..                             ...
# 145       a cylinder tied to a box
# 146         a bowl pushing a child
# 147         a teacup pushing a man
# 148       a spoon tied to a teacup
# 149      a spoon hitting an iguana
#
#                                      gpt4_raw_response  \
# 0    {'id': 'chatcmpl-9K8p1jbef4PVY49oxwHfkYQUSZNcQ...
# 1    {'id': 'chatcmpl-9K8pBjqVOsxiYeS88ENzsO3qU0yen...
# 2    {'id': 'chatcmpl-9K8q0blQqCxp4YXg8BGzwlSLd71GH...
# 3    {'id': 'chatcmpl-9K8qBoMAtpGpfUrIreg8MJviVggW7...
# 4    {'id': 'chatcmpl-9K8qzri8utjYzSdWEK4EkK6oeIkRl...
# ..                                                 ...
# 145  {'id': 'chatcmpl-9KAl2jfm8ZzAauLFtP7SGnIpnVbVD...
# 146  {'id': 'chatcmpl-9KAlzC959R7cDfs9E7pwZCXBhd2b4...
# 147  {'id': 'chatcmpl-9KAm0TCUpV9qvKnq8QAKuWMRDQRi0...
# 148  {'id': 'chatcmpl-9KAmy4cgRA9hqOUKXZPYv5qLV1HHg...
# 149  {'id': 'chatcmpl-9KAn0zeKJcFhJPiiUTl6otu4hA1Ac...
#
#                                   davinci_raw_response  \
# 0    {'id': 'cmpl-9K8p20BOcH5u0SMn0kTzRaRuRU8pn', '...
# 1    {'id': 'cmpl-9K8pDrwBGvpjkDDpORodNOScaU3S4', '...
# 2    {'id': 'cmpl-9K8q11oNS253xChNyzOet0gX0Y0dm', '...
# 3    {'id': 'cmpl-9K8qCbrk1H17tfNnZF0VJ8lk99nqi', '...
# 4    {'id': 'cmpl-9K8r0TZ9KwsZRZV46cwb5VLZQTFd7', '...
# ..                                                 ...
# 145  {'id': 'cmpl-9KAl3vDxswaUgndsO1xKowwC5OF5x', '...
# 146  {'id': 'cmpl-9KAm0VWu42w6aLBiHLoaNNgaSZhaY', '...
# 147  {'id': 'cmpl-9KAm1oupxxs9XsYbrmT88ECQfhEGF', '...
# 148  {'id': 'cmpl-9KAmz2SoVLa5EdKebbujFTZfdbmUo', '...
# 149  {'id': 'cmpl-9KAn1RhplHtagsEgRBRUZVslwOOmC', '...
#
#                                   babbage_raw_response  \
# 0    {'id': 'cmpl-9K8p2CjRwrkqytjorjYCk2amFTOm1', '...
# 1    {'id': 'cmpl-9K8pDP7aW4TMfYnF6xzvY5ijdYP1s', '...
# 2    {'id': 'cmpl-9K8q16HIPgs3tM2MEBg6tXXG9Cd22', '...
# 3    {'id': 'cmpl-9K8qCGQp4ORPJsgP1SusicLjTRyIC', '...
# 4    {'id': 'cmpl-9K8r0jh1cSZ0xZMulgIqknVF46dfK', '...
# ..                                                 ...
# 145  {'id': 'cmpl-9KAl3aqTNt0Expx9X3mmIzibno4a7', '...
# 146  {'id': 'cmpl-9KAm0R39nQcOyR9dpSl0w2HxpwJn7', '...
# 147  {'id': 'cmpl-9KAm1cM0OgnlroyGzbxJ8Pw40wRbc', '...
# 148  {'id': 'cmpl-9KAn0zjlnDpqUfwKrll3gvEIGGEmS', '...
# 149  {'id': 'cmpl-9KAn12R8MPNVrLFFYgTRf5qVQJ0R4', '...
#
#                                            gpt4_tokens  \
# 0              ['a', ' blanket', ' in', ' a', ' bowl']
# 1    ['a', ' blanket', ' near', ' a', ' te', 'ac', ...
# 2    ['a', ' bowl', ' hanging', ' over', ' a', ' bl...
# 3    ['a', ' box', ' hanging', ' over', ' a', ' bowl']
# 4                  ['a', ' box', ' in', ' a', ' bowl']
# ..                                                 ...
# 145   ['a', ' cylinder', ' tied', ' to', ' a', ' box']
# 146         ['a', ' bowl', ' pushing', ' a', ' child']
# 147  ['a', ' te', 'ac', 'up', ' pushing', ' a', ' m...
# 148  ['a', ' spoon', ' tied', ' to', ' a', ' te', '...
# 149  ['a', ' spoon', ' hitting', ' an', ' ig', 'u',...
#
#                                         davinci_tokens  \
# 0              ['a', ' blanket', ' in', ' a', ' bowl']
# 1    ['a', ' blanket', ' near', ' a', ' te', 'ac', ...
# 2    ['a', ' bowl', ' hanging', ' over', ' a', ' bl...
# 3    ['a', ' box', ' hanging', ' over', ' a', ' bowl']
# 4                  ['a', ' box', ' in', ' a', ' bowl']
# ..                                                 ...
# 145   ['a', ' cylinder', ' tied', ' to', ' a', ' box']
# 146         ['a', ' bowl', ' pushing', ' a', ' child']
# 147  ['a', ' te', 'ac', 'up', ' pushing', ' a', ' m...
# 148  ['a', ' spoon', ' tied', ' to', ' a', ' te', '...
# 149  ['a', ' spoon', ' hitting', ' an', ' ig', 'u',...
#
#                                         babbage_tokens  \
# 0              ['a', ' blanket', ' in', ' a', ' bowl']
# 1    ['a', ' blanket', ' near', ' a', ' te', 'ac', ...
# 2    ['a', ' bowl', ' hanging', ' over', ' a', ' bl...
# 3    ['a', ' box', ' hanging', ' over', ' a', ' bowl']
# 4                  ['a', ' box', ' in', ' a', ' bowl']
# ..                                                 ...
# 145   ['a', ' cylinder', ' tied', ' to', ' a', ' box']
# 146         ['a', ' bowl', ' pushing', ' a', ' child']
# 147  ['a', ' te', 'ac', 'up', ' pushing', ' a', ' m...
# 148  ['a', ' spoon', ' tied', ' to', ' a', ' te', '...
# 149  ['a', ' spoon', ' hitting', ' an', ' ig', 'u',...
#
#                                          gpt4_logprobs  \
# 0    [-0.01658686, -1.2590794e-05, -1.2664457e-06, ...
# 1    [-0.020459667, -1.1279553e-05, -9.0883464e-07,...
# 2    [-0.012703411, -5.9153886e-06, -1.9361265e-07,...
# 3    [-0.015751379, -2.4584822e-06, -7.89631e-07, -...
# 4    [-0.013673756, -5.7961847e-06, -3.0545007e-06,...
# ..                                                 ...
# 145  [-0.012616416, -4.246537e-06, -6.704273e-07, -...
# 146  [-0.031383984, -1.147242e-06, -2.577686e-06, -...
# 147  [-0.13089418, -3.1281633e-07, 0.0, -3.190179e-...
# 148  [-0.044117846, -4.3202e-07, -6.704273e-07, -1....
# 149  [-0.019537603, -1.0280384e-06, -5.5122365e-07,...
#
#                                       davinci_logprobs  \
# 0    [None, -12.590252, -4.484625, -2.0981426, -6.4...
# 1    [None, -12.590252, -8.855719, -2.3339164, -9.6...
# 2    [None, -10.496136, -9.833548, -2.9936056, -1.4...
# 3    [None, -9.827068, -9.932357, -3.4665048, -2.00...
# 4    [None, -9.827068, -4.395247, -2.3535228, -7.3895]
# ..                                                 ...
# 145  [None, -11.774822, -11.591064, -0.88436085, -0...
# 146  [None, -10.496136, -12.36553, -2.6788495, -5.5...
# 147  [None, -7.76408, -6.1830926, -0.317, -12.66834...
# 148  [None, -11.817791, -10.724584, -0.6521324, -0....
# 149  [None, -11.817791, -12.458959, -4.266213, -10....
#
#                                       babbage_logprobs  \
# 0    [None, -11.456543, -4.099536, -2.359209, -7.42...
# 1    [None, -11.456543, -7.958911, -2.4094727, -8.4...
# 2    [None, -10.874512, -10.25486, -2.2674778, -1.8...
# 3    [None, -9.552246, -10.26738, -3.530322, -2.928...
# 4    [None, -9.552246, -4.042282, -2.3188457, -6.73...
# ..                                                 ...
# 145  [None, -11.41748, -11.816972, -0.914863, -0.99...
# 146  [None, -10.874512, -12.088844, -3.1677837, -5....
# 147  [None, -7.5654297, -6.744443, -0.29875097, -13...
# 148  [None, -11.169434, -10.952009, -0.60070205, -1...
# 149  [None, -11.169434, -11.7233715, -5.024222, -8....
#
#                                             gpt4_probs  \
# 0    [0.9835499445321081, 0.9999874092852638, 0.999...
# 1    [0.9797482118622545, 0.9999887205106139, 0.999...
# 2    [0.9873769367355467, 0.9999940846288958, 0.999...
# 3    [0.9843720251918819, 0.9999975415208221, 0.999...
# 4    [0.9864193051535185, 0.9999942038320978, 0.999...
# ..                                                 ...
# 145  [0.9874628373285649, 0.9999957534720165, 0.999...
# 146  [0.9691033814299655, 0.9999988527586581, 0.999...
# 147  [0.8773106064875892, 0.9999996871837189, 1.0, ...
# 148  [0.9568411909216483, 0.9999995679800934, 0.999...
# 149  [0.9806520190374717, 0.9999989719621284, 0.999...
#
#                                          davinci_probs  \
# 0    [None, 3.405046370841077e-06, 0.01128111714656...
# 1    [None, 3.405046370841077e-06, 0.00014256407645...
# 2    [None, 2.7643056021483536e-05, 5.3622167640702...
# 3    [None, 5.397076753083862e-05, 4.85771646814216...
# 4    [None, 5.397076753083862e-05, 0.01233583299835...
# ..                                                 ...
# 145  [None, 7.695906452616838e-06, 9.24836295444698...
# 146  [None, 2.7643056021483536e-05, 4.2630316323498...
# 147  [None, 0.00042472018249749104, 0.0020640347402...
# 148  [None, 7.372224983284195e-06, 2.19974504490745...
# 149  [None, 7.372224983284195e-06, 3.88278064471090...
#
#                                          babbage_probs  gpt4_avg_prob  \
# 0    [None, 1.0580022551655034e-05, 0.0165803669074...       0.996707
# 1    [None, 1.0580022551655034e-05, 0.0003495335523...       0.997101
# 2    [None, 1.8934744315046445e-05, 3.5186080285656...       0.997893
# 3    [None, 7.104152448363382e-05, 3.47482968036238...       0.997394
# 4    [None, 7.104152448363382e-05, 0.01755736076836...       0.997282
# ..                                                 ...            ...
# 145  [None, 1.1001488237490903e-05, 7.3782653087211...       0.997909
# 146  [None, 1.8934744315046445e-05, 5.6218824197977...       0.993817
# 147  [None, 0.0005180547118242447, 0.00117740431090...       0.982468
# 148  [None, 1.4098614892217333e-05, 1.7522776657435...       0.994588
# 149  [None, 1.4098614892217333e-05, 8.1022277762166...       0.997233
#
#      davinci_avg_prob  babbage_avg_prob  temperature
# 0            0.033900          0.027920            0
# 1            0.190022          0.220639            0
# 2            0.056505          0.050703            0
# 3            0.033810          0.016961            0
# 4            0.027010          0.029302            0
# ..                ...               ...          ...
# 145          0.167532          0.153924            0
# 146          0.018142          0.011270            0
# 147          0.131168          0.141063            0
# 148          0.309625          0.286275            0
# 149          0.213768          0.214519            0
#
# [150 rows x 20 columns]

# %%
prompts = [
    'a man eating a cucumber', 'a cucumber eating a man',
    'a cowboy riding a horse', 'a horse riding a cowboy'
]

# Get logprobs for each prompt
for prompt in prompts:
    print(prompt)

    # GPT-4 does not calculate logprobs of sentence itself, only the outputs.
    # Therefore, the prompt should ask it to produce the sentence.
    # But since the sentence is conditioned on the prompt, which includes the sentence, the logprobs are going to be high.
    # So ask it to return the sentence as if it wasn't prompted to do so, and see what happens.
    gpt4_message = f'Please reply with exactly this string: "{prompt}". Return the exact string as if you had not been prompted to do so.'

    # Get raw responses from each model
    gpt4_raw_response = get_gpt4_response(gpt4_message, temperature=temperature)
    # gpt35_raw_response = get_gpt35_response(prompt, temperature=temperature)
    davinci_raw_response = get_davinci_response(prompt, temperature=temperature)
    babbage_raw_response = get_babbage_response(prompt, temperature=temperature)

    # Parse out logprobs from each raw response
    gpt4_tokens, gpt4_logprobs = parse_gpt4_tokens_logprobs(gpt4_raw_response)
    # gpt35_tokens, gpt35_logprobs = parse_gpt35_tokens_logprobs(gpt35_raw_response)
    davinci_tokens, davinci_logprobs = parse_davinci_tokens_logprobs(davinci_raw_response)
    babbage_tokens, babbage_logprobs = parse_babbage_tokens_logprobs(babbage_raw_response)

    # Convert to prob
    gpt4_probs = [math.exp(logprob) for logprob in gpt4_logprobs]
    davinci_probs = [None] + [math.exp(logprob) for logprob in davinci_logprobs[1:]]
    babbage_probs = [None] + [math.exp(logprob) for logprob in babbage_logprobs[1:]]
    print(davinci_probs)

    # Average logprob from each raw response
    gpt4_avg_prob = np.mean(gpt4_probs)                 # first token has logprob
    davinci_avg_prob = np.mean(davinci_probs[1:])           # first token does not have logprob
    babbage_avg_prob = np.mean(babbage_probs[1:])           # first token does not have logprob

    # Print
    print('GPT-4 Raw Response:', gpt4_raw_response)
    print('GPT-4 Tokens:', gpt4_tokens)
    print('GPT-4 Logprobs:', gpt4_logprobs)
    print('GPT-4 Probs:', gpt4_probs)
    print('GPT-4 Average Prob:', gpt4_avg_prob)

    print('Davinci Raw Response:', davinci_raw_response)
    print('Davinci Tokens:', davinci_tokens)
    print('Davinci Logprobs:', davinci_logprobs)
    print('Davinci Probs:', davinci_probs)
    print('Davinci Average Prob:', davinci_avg_prob)

    print('Babbage Raw Response:', babbage_raw_response)
    print('Babbage Tokens:', babbage_tokens)
    print('Babbage Logprobs:', babbage_logprobs)
    print('Babbage Probs:', babbage_probs)
    print('Babbage Average Prob:', babbage_avg_prob)
    
    print()
# Out:
# a man eating a cucumber
# [None, 0.0006400757687154789, 0.0003442573740363612, 0.1515100984225026, 0.0018314743147578175]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KCnL7plXFhHRwo8rZoMPy5hYMlIF', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.017854782, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.017854782}, {'token': '"a', 'bytes': [34, 97], 'logprob': -4.0491047}, {'token': 'A', 'bytes': [65], 'logprob': -8.53348}, {'token': '"A', 'bytes': [34, 65], 'logprob': -10.68973}, {'token': '"', 'bytes': [34], 'logprob': -11.299105}]}, {'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -2.6968896e-06, 'top_logprobs': [{'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -2.6968896e-06}, {'token': ' ', 'bytes': [32], 'logprob': -14.828128}, {'token': ' Man', 'bytes': [32, 77, 97, 110], 'logprob': -15.218753}, {'token': ' woman', 'bytes': [32, 119, 111, 109, 97, 110], 'logprob': -15.695315}, {'token': ' ma', 'bytes': [32, 109, 97], 'logprob': -15.89844}]}, {'token': ' eating', 'bytes': [32, 101, 97, 116, 105, 110, 103], 'logprob': -9.0883464e-07, 'top_logprobs': [{'token': ' eating', 'bytes': [32, 101, 97, 116, 105, 110, 103], 'logprob': -9.0883464e-07}, {'token': 'eating', 'bytes': [101, 97, 116, 105, 110, 103], 'logprob': -15.453126}, {'token': ' eats', 'bytes': [32, 101, 97, 116, 115], 'logprob': -15.765626}, {'token': ' drinking', 'bytes': [32, 100, 114, 105, 110, 107, 105, 110, 103], 'logprob': -16.03125}, {'token': ' eat', 'bytes': [32, 101, 97, 116], 'logprob': -16.71875}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -1.504853e-06, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -1.504853e-06}, {'token': ' cucumber', 'bytes': [32, 99, 117, 99, 117, 109, 98, 101, 114], 'logprob': -13.718752}, {'token': ' ', 'bytes': [32], 'logprob': -16.484377}, {'token': ' an', 'bytes': [32, 97, 110], 'logprob': -17.109377}, {'token': 'a', 'bytes': [97], 'logprob': -17.531252}]}, {'token': ' cucumber', 'bytes': [32, 99, 117, 99, 117, 109, 98, 101, 114], 'logprob': -4.3202e-07, 'top_logprobs': [{'token': ' cucumber', 'bytes': [32, 99, 117, 99, 117, 109, 98, 101, 114], 'logprob': -4.3202e-07}, {'token': 'ucumber', 'bytes': [117, 99, 117, 109, 98, 101, 114], 'logprob': -15.484375}, {'token': ' cuc', 'bytes': [32, 99, 117, 99], 'logprob': -17.109375}, {'token': ' ', 'bytes': [32], 'logprob': -17.28125}, {'token': ' cu', 'bytes': [32, 99, 117], 'logprob': -17.546875}]}]}, 'message': {'content': 'a man eating a cucumber', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602771, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' man', ' eating', ' a', ' cucumber']
# GPT-4 Logprobs: [-0.017854782, -2.6968896e-06, -9.0883464e-07, -1.504853e-06, -4.3202e-07]
# GPT-4 Probs: [0.9823036701756364, 0.9999973031140366, 0.999999091165773, 0.9999984951481323, 0.9999995679800934]
# GPT-4 Average Prob: 0.9964596255167344
# Davinci Raw Response: {'id': 'cmpl-9KCnLU0xlqsslznvwrKJBKYcVGCmi', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 5, 12, 14], 'token_logprobs': [None, -7.353924, -7.974121, -1.887103, -6.302634], 'tokens': ['a', ' man', ' eating', ' a', ' cucumber'], 'top_logprobs': None}, 'text': 'a man eating a cucumber', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602771, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' man', ' eating', ' a', ' cucumber']
# Davinci Logprobs: [None, -7.353924, -7.974121, -1.887103, -6.302634]
# Davinci Probs: [None, 0.0006400757687154789, 0.0003442573740363612, 0.1515100984225026, 0.0018314743147578175]
# Davinci Average Prob: 0.03858147647000307
# Babbage Raw Response: {'id': 'cmpl-9KCnMfuDOk4agV56qyvnb65296Kif', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 5, 12, 14], 'token_logprobs': [None, -6.8950195, -8.369719, -2.1099038, -6.0233927], 'tokens': ['a', ' man', ' eating', ' a', ' cucumber'], 'top_logprobs': None}, 'text': 'a man eating a cucumber', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602772, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' man', ' eating', ' a', ' cucumber']
# Babbage Logprobs: [None, -6.8950195, -8.369719, -2.1099038, -6.0233927]
# Babbage Probs: [None, 0.0010128172244049777, 0.0002317806749577928, 0.12124963008676527, 0.0024214404224399016]
# Babbage Average Prob: 0.031228917102141984
#
# a cucumber eating a man
# [None, 3.5131341453440258e-06, 0.00010715308982673734, 0.047280685843183796, 0.0019392197064236588]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KCnMXuuFLR7Xdtd5lUNJlrS1rYdj', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.045218617, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.045218617}, {'token': '"a', 'bytes': [34, 97], 'logprob': -3.1233437}, {'token': 'A', 'bytes': [65], 'logprob': -9.123343}, {'token': 'I', 'bytes': [73], 'logprob': -10.154593}, {'token': '"A', 'bytes': [34, 65], 'logprob': -11.123343}]}, {'token': ' cucumber', 'bytes': [32, 99, 117, 99, 117, 109, 98, 101, 114], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': ' cucumber', 'bytes': [32, 99, 117, 99, 117, 109, 98, 101, 114], 'logprob': -3.1281633e-07}, {'token': ' cuc', 'bytes': [32, 99, 117, 99], 'logprob': -15.875}, {'token': ' ', 'bytes': [32], 'logprob': -16.6875}, {'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -17.4375}, {'token': ' cu', 'bytes': [32, 99, 117], 'logprob': -17.921875}]}, {'token': ' eating', 'bytes': [32, 101, 97, 116, 105, 110, 103], 'logprob': -7.3458323e-06, 'top_logprobs': [{'token': ' eating', 'bytes': [32, 101, 97, 116, 105, 110, 103], 'logprob': -7.3458323e-06}, {'token': 'eating', 'bytes': [101, 97, 116, 105, 110, 103], 'logprob': -13.265633}, {'token': ' Eating', 'bytes': [32, 69, 97, 116, 105, 110, 103], 'logprob': -14.328133}, {'token': ' biting', 'bytes': [32, 98, 105, 116, 105, 110, 103], 'logprob': -14.484383}, {'token': ' drinking', 'bytes': [32, 100, 114, 105, 110, 107, 105, 110, 103], 'logprob': -14.734383}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -9.0883464e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -9.0883464e-07}, {'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -14.203126}, {'token': ' ', 'bytes': [32], 'logprob': -17.5}, {'token': 'a', 'bytes': [97], 'logprob': -18.03125}, {'token': ' am', 'bytes': [32, 97, 109], 'logprob': -18.664062}]}, {'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -1.7432603e-06, 'top_logprobs': [{'token': ' man', 'bytes': [32, 109, 97, 110], 'logprob': -1.7432603e-06}, {'token': ' ', 'bytes': [32], 'logprob': -15.031252}, {'token': ' ma', 'bytes': [32, 109, 97], 'logprob': -15.031252}, {'token': ' mand', 'bytes': [32, 109, 97, 110, 100], 'logprob': -15.640627}, {'token': '-man', 'bytes': [45, 109, 97, 110], 'logprob': -15.984377}]}]}, 'message': {'content': 'a cucumber eating a man', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602772, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' cucumber', ' eating', ' a', ' man']
# GPT-4 Logprobs: [-0.045218617, -3.1281633e-07, -7.3458323e-06, -9.0883464e-07, -1.7432603e-06]
# GPT-4 Probs: [0.9557885073751309, 0.9999996871837189, 0.9999926541946805, 0.999999091165773, 0.9999982567412194]
# GPT-4 Average Prob: 0.9911556393321046
# Davinci Raw Response: {'id': 'cmpl-9KCnNkhLwE1Rp8mY5vXrP3FBzQOJs', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 10, 17, 19], 'token_logprobs': [None, -12.559002, -9.141252, -3.0516534, -6.2454696], 'tokens': ['a', ' cucumber', ' eating', ' a', ' man'], 'top_logprobs': None}, 'text': 'a cucumber eating a man', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602773, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' cucumber', ' eating', ' a', ' man']
# Davinci Logprobs: [None, -12.559002, -9.141252, -3.0516534, -6.2454696]
# Davinci Probs: [None, 3.5131341453440258e-06, 0.00010715308982673734, 0.047280685843183796, 0.0019392197064236588]
# Davinci Average Prob: 0.012332642943394884
# Babbage Raw Response: {'id': 'cmpl-9KCnNHj9sC9pmRZU8NIpB1q9kGAV1', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 10, 17, 19], 'token_logprobs': [None, -12.368652, -9.711452, -3.0927408, -7.011528], 'tokens': ['a', ' cucumber', ' eating', ' a', ' man'], 'top_logprobs': None}, 'text': 'a cucumber eating a man', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602773, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' cucumber', ' eating', ' a', ' man']
# Babbage Logprobs: [None, -12.368652, -9.711452, -3.0927408, -7.011528]
# Babbage Probs: [None, 4.249743201627373e-06, 6.0585679784525264e-05, 0.04537741339694879, 0.0009014301502679701]
# Babbage Average Prob: 0.01158591974255073
#
# a cowboy riding a horse
# [None, 3.309968120137775e-06, 0.0024249509053842454, 0.3995830302305492, 0.2919478174637018]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KCoJKpdapWDwkgwIM7KSMAznvM3l', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.004701634, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.004701634}, {'token': '"a', 'bytes': [34, 97], 'logprob': -5.4734516}, {'token': 'A', 'bytes': [65], 'logprob': -7.7078266}, {'token': '"A', 'bytes': [34, 65], 'logprob': -11.395327}, {'token': '"', 'bytes': [34], 'logprob': -11.457827}]}, {'token': ' cowboy', 'bytes': [32, 99, 111, 119, 98, 111, 121], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': ' cowboy', 'bytes': [32, 99, 111, 119, 98, 111, 121], 'logprob': -3.1281633e-07}, {'token': ' cow', 'bytes': [32, 99, 111, 119], 'logprob': -16.21875}, {'token': ' ', 'bytes': [32], 'logprob': -16.5}, {'token': ' Cowboy', 'bytes': [32, 67, 111, 119, 98, 111, 121], 'logprob': -17.984375}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -18.328125}]}, {'token': ' riding', 'bytes': [32, 114, 105, 100, 105, 110, 103], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' riding', 'bytes': [32, 114, 105, 100, 105, 110, 103], 'logprob': -5.5122365e-07}, {'token': 'riding', 'bytes': [114, 105, 100, 105, 110, 103], 'logprob': -14.828126}, {'token': ' Riding', 'bytes': [32, 82, 105, 100, 105, 110, 103], 'logprob': -17.203125}, {'token': ' rode', 'bytes': [32, 114, 111, 100, 101], 'logprob': -17.5}, {'token': ' driving', 'bytes': [32, 100, 114, 105, 118, 105, 110, 103], 'logprob': -17.734375}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -1.9361265e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -1.9361265e-07}, {'token': ' horse', 'bytes': [32, 104, 111, 114, 115, 101], 'logprob': -16.421875}, {'token': ' ', 'bytes': [32], 'logprob': -17.515625}, {'token': 'a', 'bytes': [97], 'logprob': -17.875}, {'token': '\xa0', 'bytes': [194, 160], 'logprob': -18.820312}]}, {'token': ' horse', 'bytes': [32, 104, 111, 114, 115, 101], 'logprob': -2.3392786e-06, 'top_logprobs': [{'token': ' horse', 'bytes': [32, 104, 111, 114, 115, 101], 'logprob': -2.3392786e-06}, {'token': 'horse', 'bytes': [104, 111, 114, 115, 101], 'logprob': -14.140627}, {'token': ' hors', 'bytes': [32, 104, 111, 114, 115], 'logprob': -14.171877}, {'token': ' house', 'bytes': [32, 104, 111, 117, 115, 101], 'logprob': -14.953127}, {'token': ' hose', 'bytes': [32, 104, 111, 115, 101], 'logprob': -16.078127}]}]}, 'message': {'content': 'a cowboy riding a horse', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602831, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' cowboy', ' riding', ' a', ' horse']
# GPT-4 Logprobs: [-0.004701634, -3.1281633e-07, -5.5122365e-07, -1.9361265e-07, -2.3392786e-06]
# GPT-4 Probs: [0.995309401379589, 0.9999996871837189, 0.9999994487765019, 0.9999998063873687, 0.9999976607241361]
# GPT-4 Average Prob: 0.9990612008902631
# Davinci Raw Response: {'id': 'cmpl-9KCoOnDvJVcoeUOPbIeVN0xvXXa6F', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 8, 15, 17], 'token_logprobs': [None, -12.618572, -6.021944, -0.9173337, -1.2311802], 'tokens': ['a', ' cowboy', ' riding', ' a', ' horse'], 'top_logprobs': None}, 'text': 'a cowboy riding a horse', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602836, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' cowboy', ' riding', ' a', ' horse']
# Davinci Logprobs: [None, -12.618572, -6.021944, -0.9173337, -1.2311802]
# Davinci Probs: [None, 3.309968120137775e-06, 0.0024249509053842454, 0.3995830302305492, 0.2919478174637018]
# Davinci Average Prob: 0.17348977714193886
# Babbage Raw Response: {'id': 'cmpl-9KCoP5NmIlXy1baWKtoM224PT0jlF', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 8, 15, 17], 'token_logprobs': [None, -11.368652, -6.120836, -1.2587256, -1.129093], 'tokens': ['a', ' cowboy', ' riding', ' a', ' horse'], 'top_logprobs': None}, 'text': 'a cowboy riding a horse', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602837, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' cowboy', ' riding', ' a', ' horse']
# Babbage Logprobs: [None, -11.368652, -6.120836, -1.2587256, -1.129093]
# Babbage Probs: [None, 1.1551999720601053e-05, 0.002196618821889428, 0.2840157456296157, 0.32332638049750123]
# Babbage Average Prob: 0.15238757423718174
#
# a horse riding a cowboy
# [None, 2.592706899733297e-05, 0.0041022306181821904, 0.007327977661434383, 0.0007417034928380051]
# GPT-4 Raw Response: {'id': 'chatcmpl-9KCoPAIpmpYALHwEbanxSQAcRxLFE', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': {'content': [{'token': 'a', 'bytes': [97], 'logprob': -0.20182611, 'top_logprobs': [{'token': 'a', 'bytes': [97], 'logprob': -0.20182611}, {'token': '"a', 'bytes': [34, 97], 'logprob': -1.7018261}, {'token': 'I', 'bytes': [73], 'logprob': -8.233076}, {'token': 'Sure', 'bytes': [83, 117, 114, 101], 'logprob': -9.936201}, {'token': 'A', 'bytes': [65], 'logprob': -10.217451}]}, {'token': ' horse', 'bytes': [32, 104, 111, 114, 115, 101], 'logprob': -1.6240566e-06, 'top_logprobs': [{'token': ' horse', 'bytes': [32, 104, 111, 114, 115, 101], 'logprob': -1.6240566e-06}, {'token': ' house', 'bytes': [32, 104, 111, 117, 115, 101], 'logprob': -14.734377}, {'token': ' hor', 'bytes': [32, 104, 111, 114], 'logprob': -16.093752}, {'token': ' ', 'bytes': [32], 'logprob': -16.281252}, {'token': ' h', 'bytes': [32, 104], 'logprob': -16.312502}]}, {'token': ' riding', 'bytes': [32, 114, 105, 100, 105, 110, 103], 'logprob': -1.6240566e-06, 'top_logprobs': [{'token': ' riding', 'bytes': [32, 114, 105, 100, 105, 110, 103], 'logprob': -1.6240566e-06}, {'token': 'riding', 'bytes': [114, 105, 100, 105, 110, 103], 'logprob': -14.406252}, {'token': ' Riding', 'bytes': [32, 82, 105, 100, 105, 110, 103], 'logprob': -14.875002}, {'token': ' wearing', 'bytes': [32, 119, 101, 97, 114, 105, 110, 103], 'logprob': -15.718752}, {'token': ',', 'bytes': [44], 'logprob': -16.890627}]}, {'token': ' a', 'bytes': [32, 97], 'logprob': -5.5122365e-07, 'top_logprobs': [{'token': ' a', 'bytes': [32, 97], 'logprob': -5.5122365e-07}, {'token': ' cowboy', 'bytes': [32, 99, 111, 119, 98, 111, 121], 'logprob': -15.140626}, {'token': ' the', 'bytes': [32, 116, 104, 101], 'logprob': -17.09375}, {'token': ' ', 'bytes': [32], 'logprob': -17.140625}, {'token': 'a', 'bytes': [97], 'logprob': -17.851562}]}, {'token': ' cowboy', 'bytes': [32, 99, 111, 119, 98, 111, 121], 'logprob': -3.1281633e-07, 'top_logprobs': [{'token': ' cowboy', 'bytes': [32, 99, 111, 119, 98, 111, 121], 'logprob': -3.1281633e-07}, {'token': ' ', 'bytes': [32], 'logprob': -16.28125}, {'token': ' cow', 'bytes': [32, 99, 111, 119], 'logprob': -16.328125}, {'token': ' a', 'bytes': [32, 97], 'logprob': -18.390625}, {'token': ' **', 'bytes': [32, 42, 42], 'logprob': -18.546875}]}]}, 'message': {'content': 'a horse riding a cowboy', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602837, 'model': 'gpt-4', 'object': 'chat.completion', 'system_fingerprint': 'fp_2f57f81c11', 'usage': {'completion_tokens': 5, 'prompt_tokens': 36, 'total_tokens': 41}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# GPT-4 Tokens: ['a', ' horse', ' riding', ' a', ' cowboy']
# GPT-4 Logprobs: [-0.20182611, -1.6240566e-06, -1.6240566e-06, -5.5122365e-07, -3.1281633e-07]
# GPT-4 Probs: [0.8172370249335213, 0.9999983759447187, 0.9999983759447187, 0.9999994487765019, 0.9999996871837189]
# GPT-4 Average Prob: 0.9634465825566358
# Davinci Raw Response: {'id': 'cmpl-9KCoPz4iiQu5C0q9OVTdMhGpAE12R', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 14, 16], 'token_logprobs': [None, -10.560223, -5.4962244, -4.9160557, -7.206561], 'tokens': ['a', ' horse', ' riding', ' a', ' cowboy'], 'top_logprobs': None}, 'text': 'a horse riding a cowboy', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602837, 'model': 'davinci-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Davinci Tokens: ['a', ' horse', ' riding', ' a', ' cowboy']
# Davinci Logprobs: [None, -10.560223, -5.4962244, -4.9160557, -7.206561]
# Davinci Probs: [None, 2.592706899733297e-05, 0.0041022306181821904, 0.007327977661434383, 0.0007417034928380051]
# Davinci Average Prob: 0.003049459710362978
# Babbage Raw Response: {'id': 'cmpl-9KCoQ3ca0KQfJ4OjpAhfHUld36Pi2', 'choices': [{'finish_reason': 'length', 'index': 0, 'logprobs': {'text_offset': [0, 1, 7, 14, 16], 'token_logprobs': [None, -10.603027, -5.0499983, -5.571184, -7.078601], 'tokens': ['a', ' horse', ' riding', ' a', ' cowboy'], 'top_logprobs': None}, 'text': 'a horse riding a cowboy', 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'created': 1714602838, 'model': 'babbage-002', 'object': 'text_completion', 'system_fingerprint': None, 'usage': {'completion_tokens': None, 'prompt_tokens': 5, 'total_tokens': 5}, 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]}
# Babbage Tokens: ['a', ' horse', ' riding', ' a', ' cowboy']
# Babbage Logprobs: [None, -10.603027, -5.0499983, -5.571184, -7.078601]
# Babbage Probs: [None, 2.484070300427882e-05, 0.006409344342132499, 0.0038059714935784867, 0.0008429516131570355]
# Babbage Average Prob: 0.002770777037968075
